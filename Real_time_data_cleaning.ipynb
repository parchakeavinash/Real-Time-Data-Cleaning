# %%
import pandas as pd

# %%
df = pd.read_csv("data_Cleaning.csv")

# %%
df.head()
# Out:
#              Player       Span Mat  Inns  NO  Runs    HS    Ave     BF     SR  \
# 0  DG Bradman (AUS)  1928-1948  52    80  10  6996   334  99.94  9800+  58.60
# 1    HC Brook (ENG)  2022-2023  12    20   1  1181   186  62.15   1287  91.76
# 2    AC Voges (AUS)  2015-2016  20    31   7  1485  269*  61.87   2667  55.68
# 3   RG Pollock (SA)  1963-1970  23    41   4  2256   274  60.97  1707+  54.48
# 4   GA Headley (WI)  1930-1954  22    40   4  2190  270*  60.83   416+  56.00
#
#    100  50  0   4s  6s
# 0   29  13  7  626   6
# 1    4   7  1  141  23
# 2    5   4  2  186   5
# 3    7  11  1  246  11
# 4   10   5  2  104   1

# %%
# rename multiple columns in lisr

# %%
df = df.rename(columns ={'Mat':"Matche_played","Inns":"inning_bated","NO":"not_out","Runs":"Runs_scored","HS":"high_inning_score","Ave":"batt_average","BF":"ball_face","SR":"strice_rate"})

# %%
df.head()
# Out:
#              Player       Span Matche_played  inning_bated  not_out  \
# 0  DG Bradman (AUS)  1928-1948            52            80       10
# 1    HC Brook (ENG)  2022-2023            12            20        1
# 2    AC Voges (AUS)  2015-2016            20            31        7
# 3   RG Pollock (SA)  1963-1970            23            41        4
# 4   GA Headley (WI)  1930-1954            22            40        4
#
#    Runs_scored high_inning_score  batt_average ball_face strice_rate  100  50  \
# 0         6996               334         99.94     9800+       58.60   29  13
# 1         1181               186         62.15      1287       91.76    4   7
# 2         1485              269*         61.87      2667       55.68    5   4
# 3         2256               274         60.97     1707+       54.48    7  11
# 4         2190              270*         60.83      416+       56.00   10   5
#
#    0   4s  6s
# 0  7  626   6
# 1  1  141  23
# 2  2  186   5
# 3  1  246  11
# ...

# %%
#check is nay null vaues

# %%
df.isnull().sum()
# Out:
# Player               0
# Span                 0
# Matche_played        0
# inning_bated         0
# not_out              0
# Runs_scored          0
# high_inning_score    0
# batt_average         0
# ball_face            0
# strice_rate          0
# 100                  0
# 50                   0
# 0                    0
# 4s                   0
# 6s                   0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Player               False
# Span                 False
# Matche_played        False
# inning_bated         False
# not_out              False
# Runs_scored          False
# high_inning_score    False
# batt_average         False
# ball_face            False
# strice_rate          False
# 100                  False
# 50                   False
# 0                    False
# 4s                   False
# 6s                   False
# dtype: bool

# %%
# removig duplcates
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# Length: 65, dtype: bool

# %%
df[df["Player"].duplicated() == 1]
# Out:
#                  Player       Span Matche_played  inning_bated  not_out  \
# 5       GA Headley (WI)  1930-1954            22            40        4
# 41  AB de Villiers (SA)  2004-2018           114           191       18
# 53        V Kohli (IND)  2011-2024           113           191       11
#
#     Runs_scored high_inning_score  batt_average ball_face strice_rate  100  \
# 5          2190              270*         60.83      416+       56.00   10
# 41         8765              278*         50.66     16077       54.51   22
# 53         8848              254*         49.15     15924       55.56   29
#
#     50   0    4s  6s
# 5    5   2   104   1
# 41  46   8  1024  64
# 53  30  14   991  26

# %%
df[df["Player"].isin(["GA Headley (WI)",'AB de Villiers (SA)','V Kohli (IND)'])]
# Out:
#                  Player       Span Matche_played  inning_bated  not_out  \
# 4       GA Headley (WI)  1930-1954            22            40        4
# 5       GA Headley (WI)  1930-1954            22            40        4
# 40  AB de Villiers (SA)  2004-2018           114           191       18
# 41  AB de Villiers (SA)  2004-2018           114           191       18
# 52        V Kohli (IND)  2011-2024           113           191       11
# 53        V Kohli (IND)  2011-2024           113           191       11
#
#     Runs_scored high_inning_score  batt_average ball_face strice_rate  100  \
# 4          2190              270*         60.83      416+       56.00   10
# 5          2190              270*         60.83      416+       56.00   10
# 40         8765              278*         50.66     16077       54.51   22
# 41         8765              278*         50.66     16077       54.51   22
# 52         8848              254*         49.15     15924       55.56   29
# ...

# %%
df =df.drop_duplicates()

# %%
df[df["Player"].isin(["GA Headley (WI)",'AB de Villiers (SA)','V Kohli (IND)'])]
# Out:
#                  Player       Span Matche_played  inning_bated  not_out  \
# 4       GA Headley (WI)  1930-1954            22            40        4
# 40  AB de Villiers (SA)  2004-2018           114           191       18
# 52        V Kohli (IND)  2011-2024           113           191       11
#
#     Runs_scored high_inning_score  batt_average ball_face strice_rate  100  \
# 4          2190              270*         60.83      416+       56.00   10
# 40         8765              278*         50.66     16077       54.51   22
# 52         8848              254*         49.15     15924       55.56   29
#
#     50   0    4s  6s
# 4    5   2   104   1
# 40  46   8  1024  64
# 52  30  14   991  26

# %%
#split span columsn

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 60    [1965, 1981]
# 61    [2002, 2014]
# 62    [1924, 1934]
# 63    [1930, 1938]
# 64    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat = '-').str[1]
# Out:
# 0     1948
# 1     2023
# 2     2016
# 3     1970
# 4     1954
#       ...
# 60    1981
# 61    2014
# 62    1934
# 63    1938
# 64    1934
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['final_year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df.head()
# Out:
#              Player       Span Matche_played  inning_bated  not_out  \
# 0  DG Bradman (AUS)  1928-1948            52            80       10
# 1    HC Brook (ENG)  2022-2023            12            20        1
# 2    AC Voges (AUS)  2015-2016            20            31        7
# 3   RG Pollock (SA)  1963-1970            23            41        4
# 4   GA Headley (WI)  1930-1954            22            40        4
#
#    Runs_scored high_inning_score  batt_average ball_face strice_rate  100  50  \
# 0         6996               334         99.94     9800+       58.60   29  13
# 1         1181               186         62.15      1287       91.76    4   7
# 2         1485              269*         61.87      2667       55.68    5   4
# 3         2256               274         60.97     1707+       54.48    7  11
# 4         2190              270*         60.83      416+       56.00   10   5
#
#    0   4s  6s Rookie_year final_year
# 0  7  626   6        1928       1948
# ...

# %%
# drop Span column

# %%
df = df.drop(["Span"],axis = 1)

# %%
df.head()
# Out:
#              Player Matche_played  inning_bated  not_out  Runs_scored  \
# 0  DG Bradman (AUS)            52            80       10         6996
# 1    HC Brook (ENG)            12            20        1         1181
# 2    AC Voges (AUS)            20            31        7         1485
# 3   RG Pollock (SA)            23            41        4         2256
# 4   GA Headley (WI)            22            40        4         2190
#
#   high_inning_score  batt_average ball_face strice_rate  100  50  0   4s  6s  \
# 0               334         99.94     9800+       58.60   29  13  7  626   6
# 1               186         62.15      1287       91.76    4   7  1  141  23
# 2              269*         61.87      2667       55.68    5   4  2  186   5
# 3               274         60.97     1707+       54.48    7  11  1  246  11
# 4              270*         60.83      416+       56.00   10   5  2  104   1
#
#   Rookie_year final_year
# 0        1928       1948
# 1        2022       2023
# ...

# %%
df['Player'].str.split(pat = ')').str[0]
# Out:
# 0      DG Bradman (AUS
# 1        HC Brook (ENG
# 2        AC Voges (AUS
# 3       RG Pollock (SA
# 4       GA Headley (WI
#             ...
# 60     KD Walters (AUS
# 61    GC Smith (ICC/SA
# 62    WH Ponsford (AUS
# 63      SJ McCabe (AUS
# 64     DR Jardine (ENG
# Name: Player, Length: 62, dtype: object

# %%
df["Country"]=df['Player'].str.split(pat = '(').str[1]

# %%
df["Country"]=df['Country'].str.split(pat = ')').str[0]

# %%
df["Player"]=df["Player"].str.split(pat = '(').str[0]

# %%
df.head()
# Out:
#         Player Matche_played  inning_bated  not_out  Runs_scored  \
# 0  DG Bradman             52            80       10         6996
# 1    HC Brook             12            20        1         1181
# 2    AC Voges             20            31        7         1485
# 3  RG Pollock             23            41        4         2256
# 4  GA Headley             22            40        4         2190
#
#   high_inning_score  batt_average ball_face strice_rate  100  50  0   4s  6s  \
# 0               334         99.94     9800+       58.60   29  13  7  626   6
# 1               186         62.15      1287       91.76    4   7  1  141  23
# 2              269*         61.87      2667       55.68    5   4  2  186   5
# 3               274         60.97     1707+       54.48    7  11  1  246  11
# 4              270*         60.83      416+       56.00   10   5  2  104   1
#
#   Rookie_year final_year Country
# 0        1928       1948     AUS
# 1        2022       2023     ENG
# ...

# %%
# change data types

# %%
df.dtypes
# Out:
# Player                object
# Matche_played         object
# inning_bated           int64
# not_out                int64
# Runs_scored            int64
# high_inning_score     object
# batt_average         float64
# ball_face             object
# strice_rate           object
# 100                    int64
# 50                     int64
# 0                      int64
# 4s                     int64
# 6s                     int64
# Rookie_year           object
# final_year            object
# Country               object
# dtype: object

# %%
df['high_inning_score']=df['high_inning_score'].str.split(pat = '*').str[0]

# %%
df['high_inning_score']
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 60    250
# 61    277
# 62    266
# 63    232
# 64    127
# Name: high_inning_score, Length: 62, dtype: object

# %%
df['high_inning_score']= df['high_inning_score'].astype('int')

# %%
df.dtypes
# Out:
# Player                object
# Matche_played         object
# inning_bated           int64
# not_out                int64
# Runs_scored            int64
# high_inning_score      int32
# batt_average         float64
# ball_face             object
# strice_rate           object
# 100                    int64
# 50                     int64
# 0                      int64
# 4s                     int64
# 6s                     int64
# Rookie_year            int32
# final_year             int32
# Country               object
# dtype: object

# %%
df = df.astype({"Rookie_year":"int","final_year":"int"})

# %%
df['Matche_played']=df['Matche_played'].str.split(pat = '*').str[0]

# %%
df['Matche_played']= df['Matche_played'].astype('int')

# %%
df.head()
# Out:
#         Player  Matche_played  inning_bated  not_out  Runs_scored  \
# 0  DG Bradman              52            80       10         6996
# 1    HC Brook              12            20        1         1181
# 2    AC Voges              20            31        7         1485
# 3  RG Pollock              23            41        4         2256
# 4  GA Headley              22            40        4         2190
#
#    high_inning_score  batt_average ball_face strice_rate  100  50  0   4s  6s  \
# 0                334         99.94      9800       58.60   29  13  7  626   6
# 1                186         62.15      1287       91.76    4   7  1  141  23
# 2                269         61.87      2667       55.68    5   4  2  186   5
# 3                274         60.97      1707       54.48    7  11  1  246  11
# 4                270         60.83       416       56.00   10   5  2  104   1
#
#    Rookie_year  final_year Country
# 0         1928        1948     AUS
# ...

# %%
df['ball_face']=df['ball_face'].str.split(pat = '+').str[0]

# %%
df['ball_face']=df['ball_face'].str.split(pat = '-').str[0]

# %%
df['ball_face']= df['ball_face'].astype('int')

# %%
pd.set_option("display.max_rows", None)

# %%
df
# Out:
#                Player  Matche_played  inning_bated  not_out  Runs_scored  \
# 0         DG Bradman              52            80       10         6996
# 1           HC Brook              12            20        1         1181
# 2           AC Voges              20            31        7         1485
# 3         RG Pollock              23            41        4         2256
# 4         GA Headley              22            40        4         2190
# 6        H Sutcliffe              54            84        9         4555
# 7          E Paynter              20            31        5         1540
# 8      KF Barrington              82           131       15         6806
# 9          ED Weekes              48            81        5         4455
# 10        WR Hammond              85           140       16         7249
# 11         SPD Smith             107           191       25         9634
# 12         GS Sobers              93           160       21         8032
# ...

# %%
df =df.replace({'ball_face': {'': 0}})

# %%
df.dtypes
# Out:
# Player                object
# Matche_played          int32
# inning_bated           int64
# not_out                int64
# Runs_scored            int64
# high_inning_score      int32
# batt_average         float64
# ball_face              int32
# strice_rate          float64
# 100                    int64
# 50                     int64
# 0                      int64
# 4s                     int64
# 6s                     int64
# Rookie_year            int32
# final_year             int32
# Country               object
# dtype: object

# %%
df['strice_rate']=df['strice_rate'].str.split(pat = '-').str[0]

# %%
df =df.replace({'strice_rate': {'': 0}})

# %%
df['strice_rate']= df['strice_rate'].astype('float')

# %%
# create carrer length  = final_year - Rookie_year
df["carrer_length"] = df['final_year'] - df["Rookie_year"]

# %%
df
# Out:
#                Player  Matche_played  inning_bated  not_out  Runs_scored  \
# 0         DG Bradman              52            80       10         6996
# 1           HC Brook              12            20        1         1181
# 2           AC Voges              20            31        7         1485
# 3         RG Pollock              23            41        4         2256
# 4         GA Headley              22            40        4         2190
# 6        H Sutcliffe              54            84        9         4555
# 7          E Paynter              20            31        5         1540
# 8      KF Barrington              82           131       15         6806
# 9          ED Weekes              48            81        5         4455
# 10        WR Hammond              85           140       16         7249
# 11         SPD Smith             107           191       25         9634
# 12         GS Sobers              93           160       21         8032
# ...

# %%
# calculate average of carrer length

# %%
df["carrer_length"].mean()
# Out:
# 13.161290322580646

# %%
df[df["carrer_length"] > 10]["strice_rate"].mean()
# Out:
# 47.95477272727273

# %%
df[df["Rookie_year"]<1960]["Player"]
# Out:
# 0         DG Bradman
# 4         GA Headley
# 6        H Sutcliffe
# 7          E Paynter
# 8      KF Barrington
# 9          ED Weekes
# 10        WR Hammond
# 12         GS Sobers
# 14          JB Hobbs
# 15        CL Walcott
# 16          L Hutton
# 18      GE Tyldesley
# 23         AD Nourse
# 32           J Ryder
# 44       DCS Compton
# 48       FMM Worrell
# 49           CP Mead
# 56        B Mitchell
# 57    Hon.FS Jackson
# 59         RN Harvey
# 62       WH Ponsford
# 63         SJ McCabe
# 64        DR Jardine
# Name: Player, dtype: object

# %%
df[df["Rookie_year"]<1960]["Player"].count()
# Out:
# 23

# %%
df.groupby("Country")["high_inning_score"].max().to_frame("High_inning_score").reset_index().sort_values("High_inning_score", ascending = False)
# Out:
#     Country  High_inning_score
# 5    ICC/WI                400
# 0       AUS                380
# 10       SL                374
# 11       WI                365
# 1       ENG                364
# 3   ICC/PAK                329
# 2   ICC/IND                319
# 8       PAK                313
# 9        SA                278
# 4    ICC/SA                277
# 6       IND                254
# 7        NZ                251
# 12      ZIM                232

# %%
df.groupby("Country")["100","50","0"].mean()
# Out:
# C:\Users\avina\AppData\Local\Temp\ipykernel_6868\4184296570.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("Country")["100","50","0"].mean()
#                100         50          0
# Country
# AUS      20.625000  28.312500   8.500000
# ENG      12.307692  20.769231   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       17.000000  21.000000   5.500000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
